# %%
# Date: 22-5-2017

import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.models import model_from_json
from keras.layers import LSTM, Dense
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import datetime
# Out:
# Using TensorFlow backend.

# %%
# Note: caution: 十一黃金周

df_merged_volume = pd.read_csv("../data/preprocessed_input_traffic_time_and_weather_interpolate_20min_phase1and2_train.csv")

# change "Date" to datetime object
df_merged_volume['date'] = pd.to_datetime(df_merged_volume['date'])

# construct "time of day"
df_merged_volume['timeofday'] = df_merged_volume.date.apply( lambda d : d.hour+d.minute/60.)

# Select the phase 1 day

end_day = datetime.datetime(year=2016, month=10, day=18, hour=0, minute=0, second=0)

df_merged_volume = df_merged_volume[(df_merged_volume['date'] < end_day)]

# check any unreasonable rows
df_merged_volume.tail(30)

''' Cut some rows (proprecessing)'''
df_merged_volume = df_merged_volume[4:]  # Cut of NaN rows at the beginning
df_merged_volume = df_merged_volume.reset_index(drop=True)  # reindexing
df_merged_volume

''' Make the dataset stationary '''

station_cols = 6  # select the first 6 columns for stationary

df_merged_volume_copy = df_merged_volume.copy()

for i in range(1, len(df_merged_volume_copy)):
    df_merged_volume_copy.loc[i, df_merged_volume_copy.columns[0:station_cols]] = df_merged_volume.loc[i, df_merged_volume.columns[0:station_cols]] - df_merged_volume.loc[i-1, df_merged_volume.columns[0:station_cols]]

# Check Stationary dataframe

df_merged_volume_copy.tail()

## Hidden the selecting time
# select the time for training: 6:20-10:00 (5 + 6 timestamp) and 15:20-19:00 (5 + 6 timestamp)
# sel_rows = df_merged_volume_copy[ ((df_merged_volume_copy.timeofday>= 6.3) & (df_merged_volume_copy.timeofday<10)) |
#                             ((df_merged_volume_copy.timeofday>=15.3) & (df_merged_volume_copy.timeofday<19))]

## This time, training all time (24hrs) except the first non-stationary row
sel_rows = df_merged_volume_copy[1:]

# %%
sel_rows.plot.box()  # box plot
plt.show()

# %%
# Create one-hot for hour

# for i in range(24):
#     sel_rows['{}:00'.format(i)] = np.where(sel_rows.hour == i, 1, 0)

# Check all the columns
for idx, i in enumerate(sel_rows.columns):
    print(idx, i)

# select using columns

using_cols = [
#                 "(1, 0, 'cargocar')",
#                 "(1, 0, 'etc')",
#                 "(1, 0, 'motorcycle')",
#                 "(1, 0, 'privatecar')",
#                 "(1, 0, 'tot')",
#                 "(1, 0, 'unknowncar')",
#                 "(1, 1, 'cargocar')",
#                 "(1, 1, 'etc')",
#                 "(1, 1, 'motorcycle')",
#                 "(1, 1, 'privatecar')",
#                 "(1, 1, 'tot')",
#                 "(1, 1, 'unknowncar')",
#                 "(2, 0, 'cargocar')",
#                 "(2, 0, 'etc')",
#                 "(2, 0, 'motorcycle')",
#                 "(2, 0, 'privatecar')",
#                 "(2, 0, 'tot')",
#                 "(2, 0, 'unknowncar')",
#                 "(3, 0, 'cargocar')",
#                 "(3, 0, 'etc')",
#                 "(3, 0, 'motorcycle')",
#                 "(3, 0, 'privatecar')",
#                 "(3, 0, 'tot')",
#                 "(3, 0, 'unknowncar')",
#                 "(3, 1, 'cargocar')",
#                 "(3, 1, 'etc')",
#                 "(3, 1, 'motorcycle')",
#                 "(3, 1, 'privatecar')",
#                 "(3, 1, 'tot')",
#                 "(3, 1, 'unknowncar')",
#                 "('A', 2)",
#                 "('A', 3)",
                "('B', 1)",
#                 "('B', 3)",
#                 "('C', 1)",
#                 "('C', 3)",
#                 'date',  # <== Notice this
                'hour',
                'pressure',
#                 'sea_pressure',
#                 'wind_direction',
#                 'wind_speed',
                'temperature',
#                 'rel_humidity',
                'precipitation',
                'dayofweek',
                'is_holiday',
                'timeofday',
#                 '0:00',
#                 '1:00',
#                 '2:00',
#                 '3:00',
#                 '4:00',
#                 '5:00',
#                 '6:00',
#                 '7:00',
#                 '8:00',
#                 '9:00',
#                 '10:00',
#                 '11:00',
#                 '12:00',
#                 '13:00',
#                 '14:00',
#                 '15:00',
#                 '16:00',
#                 '17:00',
#                 '18:00',
#                 '19:00',
#                 '20:00',
#                 '21:00',
#                 '22:00',
#                 '23:00',
              ]

sel_rows = sel_rows[using_cols]

# split to train and valid set
train_rows = sel_rows[: -24*3*7]
valid_rows = sel_rows[-24*3*7:] # reserve 7 days for validation

# get numpy array from panda dataframe
train_arr = train_rows.values
valid_arr = valid_rows.values

# np.shape(train_arr)
# Out:
# (726, 17)
# Out:
# 0 ('A', 2)
# 1 ('A', 3)
# 2 ('B', 1)
# 3 ('B', 3)
# 4 ('C', 1)
# 5 ('C', 3)
# 6 date
# 7 hour
# 8 pressure
# 9 sea_pressure
# 10 wind_direction
# 11 wind_speed
# 12 temperature
# 13 rel_humidity
# 14 precipitation
# 15 dayofweek
# 16 is_holiday
# 17 timeofday

# %%
# Summary Stats

# train_arr.mean()
# train_rows.loc[abs(train_rows["('A', 2)"] + 814.225)<0.01]

# %%
#scale feature array to range -1 to 1

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(train_arr)
train_scaled_arr = scaler.transform(train_arr)

valid_scaled_arr = scaler.transform(valid_arr)

# %%
''' save the scaler to another file use '''
# import pickle
# scalerfile = 'scaler-A-2_phase1.sav'
# pickle.dump(scaler, open(scalerfile, 'wb'))
# Out:
# ' save the scaler to another file use '

# %%
# sample subsequence from the time series
train_seqs = []
len_seqs = len(train_scaled_arr) - 6 + 1  # 6 is window size
for i in range(len_seqs):
    train_seqs.append(train_scaled_arr[i: i+6])  # append 6 timestamps each time (5 timestamps for x, 1 timestamp for y)
train_seqs = np.stack(train_seqs)

valid_seqs = []
len_v_seqs = len(valid_scaled_arr) - 6 + 1  # 6 is window size
for i in range(len_v_seqs):
    valid_seqs.append(valid_scaled_arr[i: i+6])
valid_seqs = np.stack(valid_seqs)

# %%
# checking
train_seqs[1]
# Out:
# array([[ 0.37374879, -0.82608696, -0.48043818,  0.28063241, -1.        ,
#         -0.66666667, -1.        , -0.83098592],
#        [ 0.37374879, -0.82608696, -0.48461137,  0.31752306, -1.        ,
#         -0.66666667, -1.        , -0.8028169 ],
#        [ 0.37374879, -0.82608696, -0.48878456,  0.3544137 , -1.        ,
#         -0.66666667, -1.        , -0.77464789],
#        [ 0.37374879, -0.73913043, -0.49295775,  0.39130435, -1.        ,
#         -0.66666667, -1.        , -0.74647887],
#        [ 0.37374879, -0.73913043, -0.50130412,  0.3921827 , -1.        ,
#         -0.66666667, -1.        , -0.71830986],
#        [ 0.37374879, -0.73913043, -0.5096505 ,  0.39306105, -1.        ,
#         -0.66666667, -1.        , -0.69014085]])

# %%
#keras
#https://keras.io/getting-started/sequential-model-guide/#examples
input_dim = len(using_cols)  # The features
output_dim = 1  # 
timesteps = 5 # use 5 timesteps to predict the 6th

x_train, y_train = train_seqs[:, 0:-1], train_seqs[:, -1, 0:output_dim]  # 0:output_dim is for deciding the output features
x_valid , y_valid  =  valid_seqs[:, 0:-1],  valid_seqs[:, -1, 0:output_dim]  # 0:output_dim is for deciding the output features

# %%
y_train.shape
# Out:
# (6038, 1)

# %%
num_epochs = 100
loss_fuc = 'mean_squared_error'

# construct the callback
filepath="best_epoch_T.M._B-1_phase1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

model = Sequential()
model.add(LSTM(128, input_shape=(timesteps, input_dim), return_sequences=True))
model.add(LSTM(128))
model.add(Dense(output_dim))
model.compile(loss=loss_fuc, optimizer='adam')

# %%
## Start Training
model.summary()
history_w_model = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=num_epochs, batch_size=64, validation_data=(x_valid, y_valid))

plt.plot(history_w_model.history['loss'], label='loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.plot(history_w_model.history['val_loss'], label='Val_loss')
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 128)            70144
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 201,857
# Trainable params: 201,857
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6038 samples, validate on 499 samples
# Epoch 1/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0119Epoch 00000: val_loss improved from inf to 0.00951, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 7s - loss: 0.0119 - val_loss: 0.0095
# Epoch 2/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0050Epoch 00001: val_loss improved from 0.00951 to 0.00933, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0050 - val_loss: 0.0093
# Epoch 3/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0049Epoch 00002: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0049 - val_loss: 0.0094
# Epoch 4/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0048Epoch 00003: val_loss improved from 0.00933 to 0.00919, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0049 - val_loss: 0.0092
# Epoch 5/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0048Epoch 00004: val_loss improved from 0.00919 to 0.00918, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0048 - val_loss: 0.0092
# Epoch 6/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0047Epoch 00005: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0047 - val_loss: 0.0092
# Epoch 7/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0047Epoch 00006: val_loss improved from 0.00918 to 0.00914, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0047 - val_loss: 0.0091
# Epoch 8/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0047Epoch 00007: val_loss improved from 0.00914 to 0.00911, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0046 - val_loss: 0.0091
# Epoch 9/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0046Epoch 00008: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0046 - val_loss: 0.0094
# Epoch 10/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0046Epoch 00009: val_loss improved from 0.00911 to 0.00907, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0046 - val_loss: 0.0091
# Epoch 11/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0046Epoch 00010: val_loss improved from 0.00907 to 0.00899, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0046 - val_loss: 0.0090
# Epoch 12/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0046Epoch 00011: val_loss improved from 0.00899 to 0.00896, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0045 - val_loss: 0.0090
# Epoch 13/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00012: val_loss improved from 0.00896 to 0.00890, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 7s - loss: 0.0045 - val_loss: 0.0089
# Epoch 14/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0046Epoch 00013: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0046 - val_loss: 0.0090
# Epoch 15/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00014: val_loss improved from 0.00890 to 0.00888, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0045 - val_loss: 0.0089
# Epoch 16/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00015: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0045 - val_loss: 0.0089
# Epoch 17/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00016: val_loss improved from 0.00888 to 0.00888, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0045 - val_loss: 0.0089
# Epoch 18/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00017: val_loss improved from 0.00888 to 0.00879, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0045 - val_loss: 0.0088
# Epoch 19/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00018: val_loss improved from 0.00879 to 0.00870, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0087
# Epoch 20/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00019: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0088
# Epoch 21/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00020: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0045 - val_loss: 0.0087
# Epoch 22/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00021: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0087
# Epoch 23/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00022: val_loss improved from 0.00870 to 0.00856, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0086
# Epoch 24/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00023: val_loss improved from 0.00856 to 0.00855, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0085
# Epoch 25/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0045Epoch 00024: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0045 - val_loss: 0.0086
# Epoch 26/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00025: val_loss improved from 0.00855 to 0.00838, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0084
# Epoch 27/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00026: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0044 - val_loss: 0.0084
# Epoch 28/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00027: val_loss improved from 0.00838 to 0.00830, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0043 - val_loss: 0.0083
# Epoch 29/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0044Epoch 00028: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0044 - val_loss: 0.0084
# Epoch 30/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00029: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0043 - val_loss: 0.0085
# Epoch 31/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00030: val_loss improved from 0.00830 to 0.00822, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0043 - val_loss: 0.0082
# Epoch 32/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00031: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0042 - val_loss: 0.0083
# Epoch 33/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00032: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0043 - val_loss: 0.0084
# Epoch 34/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0042Epoch 00033: val_loss improved from 0.00822 to 0.00797, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0042 - val_loss: 0.0080
# Epoch 35/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0042Epoch 00034: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0042 - val_loss: 0.0089
# Epoch 36/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0043Epoch 00035: val_loss improved from 0.00797 to 0.00791, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0043 - val_loss: 0.0079
# Epoch 37/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00036: val_loss improved from 0.00791 to 0.00740, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0041 - val_loss: 0.0074
# Epoch 38/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0042Epoch 00037: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0042 - val_loss: 0.0083
# Epoch 39/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00038: val_loss improved from 0.00740 to 0.00725, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0041 - val_loss: 0.0073
# Epoch 40/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0042Epoch 00039: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0042 - val_loss: 0.0075
# Epoch 41/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00040: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0041 - val_loss: 0.0076
# Epoch 42/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00041: val_loss improved from 0.00725 to 0.00707, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 7s - loss: 0.0041 - val_loss: 0.0071
# Epoch 43/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00042: val_loss improved from 0.00707 to 0.00696, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 7s - loss: 0.0040 - val_loss: 0.0070
# Epoch 44/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00043: val_loss improved from 0.00696 to 0.00689, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0041 - val_loss: 0.0069
# Epoch 45/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00044: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0041 - val_loss: 0.0077
# Epoch 46/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00045: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0040 - val_loss: 0.0077
# Epoch 47/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00046: val_loss improved from 0.00689 to 0.00674, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0067
# Epoch 48/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00047: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0073
# Epoch 49/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00048: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0071
# Epoch 50/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00049: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0040 - val_loss: 0.0078
# Epoch 51/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00050: val_loss did not improve
# 6038/6038 [==============================] - 7s - loss: 0.0040 - val_loss: 0.0078
# Epoch 52/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00051: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0040 - val_loss: 0.0082
# Epoch 53/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00052: val_loss improved from 0.00674 to 0.00672, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0039 - val_loss: 0.0067
# Epoch 54/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00053: val_loss improved from 0.00672 to 0.00635, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 6s - loss: 0.0040 - val_loss: 0.0064
# Epoch 55/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00054: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0039 - val_loss: 0.0081
# Epoch 56/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00055: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0039 - val_loss: 0.0068
# Epoch 57/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0041Epoch 00056: val_loss did not improve
# 6038/6038 [==============================] - 7s - loss: 0.0041 - val_loss: 0.0071
# Epoch 58/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00057: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0040 - val_loss: 0.0082
# Epoch 59/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00058: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0039 - val_loss: 0.0065
# Epoch 60/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00059: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0067
# Epoch 61/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00060: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0039 - val_loss: 0.0068
# Epoch 62/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00061: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0039 - val_loss: 0.0073
# Epoch 63/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00062: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0075
# Epoch 64/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00063: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0039 - val_loss: 0.0064
# Epoch 65/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00064: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0064
# Epoch 66/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00065: val_loss improved from 0.00635 to 0.00605, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0060
# Epoch 67/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00066: val_loss improved from 0.00605 to 0.00601, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0039 - val_loss: 0.0060
# Epoch 68/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00067: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0078
# Epoch 69/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0040Epoch 00068: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0075
# Epoch 70/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0039Epoch 00069: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0039 - val_loss: 0.0075
# Epoch 71/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00070: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0038 - val_loss: 0.0062
# Epoch 72/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00071: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0038 - val_loss: 0.0062
# Epoch 73/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00072: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0077
# Epoch 74/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00073: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0038 - val_loss: 0.0072
# Epoch 75/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00074: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0077
# Epoch 76/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00075: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0038 - val_loss: 0.0074
# Epoch 77/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00076: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0067
# Epoch 78/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00077: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0069
# Epoch 79/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00078: val_loss improved from 0.00601 to 0.00580, saving model to best_epoch_T.M._B-1_phase1.hdf5
# 6038/6038 [==============================] - 5s - loss: 0.0038 - val_loss: 0.0058
# Epoch 80/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00079: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0067
# Epoch 81/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00080: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0037 - val_loss: 0.0060
# Epoch 82/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00081: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0077
# Epoch 83/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00082: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0063
# Epoch 84/100
# 6016/6038 [============================>.] - ETA: 4s - loss: 0.0037 Epoch 00083: val_loss did not improve
# 6038/6038 [==============================] - 1120s - loss: 0.0036 - val_loss: 0.0068
# Epoch 85/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00084: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0078
# Epoch 86/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00085: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0075
# Epoch 87/100
# 5952/6038 [============================>.] - ETA: 0s - loss: 0.0038Epoch 00086: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0066
# Epoch 88/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0035Epoch 00087: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0035 - val_loss: 0.0078
# Epoch 89/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0035Epoch 00088: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0035 - val_loss: 0.0080
# Epoch 90/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00089: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0036 - val_loss: 0.0067
# Epoch 91/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00090: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0036 - val_loss: 0.0073
# Epoch 92/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00091: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0036 - val_loss: 0.0077
# Epoch 93/100
# 6016/6038 [============================>.] - ETA: 5s - loss: 0.0035 Epoch 00092: val_loss did not improve
# 6038/6038 [==============================] - 1580s - loss: 0.0035 - val_loss: 0.0077
# Epoch 94/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00093: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0036 - val_loss: 0.0074
# Epoch 95/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0035Epoch 00094: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0035 - val_loss: 0.0079
# Epoch 96/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0035Epoch 00095: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0035 - val_loss: 0.0076
# Epoch 97/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00096: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0037 - val_loss: 0.0081
# Epoch 98/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0034Epoch 00097: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0034 - val_loss: 0.0082
# Epoch 99/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0035Epoch 00098: val_loss did not improve
# 6038/6038 [==============================] - 5s - loss: 0.0035 - val_loss: 0.0066
# Epoch 100/100
# 6016/6038 [============================>.] - ETA: 0s - loss: 0.0036Epoch 00099: val_loss did not improve
# 6038/6038 [==============================] - 6s - loss: 0.0036 - val_loss: 0.0080

# %%
''' Save Model '''

# serialize model to JSON

# model_json = model.to_json()
# with open("model_T.M._A-2-p1.json", "w") as json_file:
#     json_file.write(model_json)

# %%
''' Load the saved model '''

# load json and create model

# json_file = open('model_500x5_300e.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()

# loaded_model = model_from_json(loaded_model_json)

# %%
# Notes: last best model: 0.00175
# load weights into the model
model.load_weights("best_epoch_T.M._B-1_phase1.hdf5")
print("Loaded model from disk")

model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Loaded model from disk

# %%
''' === Prediction ===
Procedure:
1. Load CSV
2. to_datetime
3. create timeofday column
4. select the time for training: 6:00-8:00 (6 timestamps) and 15:00-17:00 (6 timestamps)
5. change it to stationary
6. Use using_cols to select the features
7. change to np array
8. MinMaxScaler
9. make the sequences tensor as input
10. make a forloop for prediction

'''
# 1. Load CSV - Vol + Route + Weather (Only Weather is 24-hour data)
df_pred = pd.read_csv('../data/preprocessed_input_interpolate_20min_phase1and2_train.csv')

# 2. to_datetime
df_pred['date'] = pd.to_datetime(df_pred['date'])

# 3. create timeofday column
df_pred['timeofday'] = df_pred.date.apply( lambda d : d.hour+d.minute/60.)

# Select the checking days (No need to real final test)

start_day = datetime.datetime(year=2016, month=10, day=18, hour=1, minute=0, second=0)
end_day = datetime.datetime(year=2016, month=10, day=24, hour=23, minute=0, second=0)

df_pred_sel = df_pred[(df_pred['date'] > start_day) & (df_pred['date'] < end_day)]

# 4. select the time for training

df_pred_sel_time = df_pred_sel[ ((df_pred_sel.timeofday>= 6) & (df_pred_sel.timeofday<8)) |
                            ((df_pred_sel.timeofday>=15) & (df_pred_sel.timeofday<17))]

df_feedin_weather_sel_time = df_pred_sel[ ((df_pred_sel.timeofday>= 8) & (df_pred_sel.timeofday<10)) |
                            ((df_pred_sel.timeofday>=17) & (df_pred_sel.timeofday<19))]

# Checking
df_pred_sel_time.iloc[12]

# 5. change it to stationary
df_pred_sel_time = df_pred_sel_time.reset_index(drop=True)

df_pred_sel_time_copy = df_pred_sel_time.copy()

for i in range(len(df_pred_sel_time_copy)//6):  # make the loop for 14 time slots (2 different time slot x 7days)
    for t in range(5):  #  Do the "difference" 5 times every loop
        start_idx = i*6 + t + 1  # Add 1 is for starting it from index 1 in every 6-space time slot
        df_pred_sel_time_copy.loc[start_idx, df_pred_sel_time_copy.columns[0:36]] = df_pred_sel_time.loc[start_idx, df_pred_sel_time.columns[0:36]] - df_pred_sel_time.loc[start_idx-1, df_pred_sel_time.columns[0:36]]

# Create one-hot for it
# for i in range(24):
#     df_pred_sel_time_copy['{}:00'.format(i)] = np.where(df_pred_sel_time_copy.hour == i, 1, 0)
#     df_feedin_weather_sel_time['{}:00'.format(i)] = np.where(df_feedin_weather_sel_time.hour == i, 1, 0)

# 6. Use using_cols to select the features

sel_rows_pred = df_pred_sel_time_copy[ using_cols ]

sel_rows_feedin_weather = df_feedin_weather_sel_time[using_cols[output_dim:]]

sel_rows_pred

# 7. change to np array
pred_arr = sel_rows_pred.values

feedin_weather_arr = sel_rows_feedin_weather.values

# 8. MinMaxScaler
pred_arr_scaled = scaler.transform(pred_arr)

# add some dummy cells in front of the weather_array for transform
temp_arr = np.zeros((84,output_dim))
feedin_weather_arr = np.concatenate([temp_arr, feedin_weather_arr], axis=1)

feedin_weather_arr_scaled = scaler.transform(feedin_weather_arr)

# Now pred_arr_scaled is (84 x features)

# 9. make the sequences tensor as input
# Put into the model to get the prediction

ans_arr = []  # For holding the output answer
    
for i in range(len(pred_arr_scaled)//6):  # make the loop for 14 time slots (2 different time slot x 7days)
    # creating pre_seq
    pred_seq = []
    for t in range(5):  #  Do the "difference" 5 times every loop
        k = i*6 + t + 1  # Add 1 is for starting it from index 1 in every 6-space time slot, to ignore the first index which is non-stationary
        pred_seq.append(pred_arr_scaled[k])  # creating a sequence for a time slot
    
    # creating feedin_weather_seq
    feedin_weather_seq = []
    for t in range(6):  #  Do 6 times every loop
        k = i*6 + t  #
        feedin_weather_seq.append(feedin_weather_arr_scaled[k])


    pred_seq = np.stack(pred_seq)  # change back to the numpy array (2D)
    pred_seq = pred_seq.reshape(1, pred_seq.shape[0], pred_seq.shape[1])  # change to numpy 3D as input

    feedin_weather_seq = np.stack(feedin_weather_seq)  # change back to the numpy array (2D)
    feedin_weather_seq = feedin_weather_seq.reshape(1, feedin_weather_seq.shape[0], feedin_weather_seq.shape[1])  # change to numpy 3D as input

    for q in range(6):
        # predict next timestamp
        output_pred = model.predict(pred_seq)  # get one prediction output (size (1 x output feature(s)))
        ans_arr.append(output_pred)

        # update the input seq
        for j in range(1,5):
            pred_seq[0][j-1] = pred_seq[0][j]
        pred_seq[0][4] = feedin_weather_seq[0][q]
        pred_seq[0][4][0:output_dim] = output_pred[0]

# 10. Backward to the non-stationary, correct scale output

#  Helper functions

def backward_scaler(nn_output):
    tmp = np.zeros(input_dim)
    tmp[0:output_dim] = nn_output
    tmp = scaler.inverse_transform(tmp)
    return tmp[0:output_dim]

def decode(last_timestamp_values, nn_output):
    tmp = np.zeros(input_dim)
    tmp[0:output_dim] = nn_output
    tmp = scaler.inverse_transform(tmp)
    return last_timestamp_values + tmp[0:output_dim]

# create the non-stationary 6:40 and 16:40 for decoding
df_non_station_sel_time = df_pred_sel[ ((df_pred_sel.timeofday>= 7.5) & (df_pred_sel.timeofday<8)) |
                            ((df_pred_sel.timeofday>=16.5) & (df_pred_sel.timeofday<17))]

''' Output the non-stationary Answers (allAns)'''

tmp = df_non_station_sel_time[using_cols[0:output_dim]].values
allAns = []
for i in range(len(tmp)):
    seed = tmp[i]  # non-stationary for reconstructing a sequence
    segmentAns = []
    for timestep in range(6):
        seed = decode(seed, ans_arr[i*6+timestep])
        segmentAns.append(seed)
    allAns.append(segmentAns)

# Change back to np array for easy visualize
allAns = np.array(allAns)

# Checking
for i in allAns:
    print(i)

# 11. Output the CSV file

# create the datetime objects
import datetime

pred_start_date = 18


start_8am = datetime.datetime(year=2016, month=10, day=pred_start_date, hour=8, minute=0, second=0)
start_5pm = datetime.datetime(year=2016, month=10, day=pred_start_date, hour=17, minute=0, second=0)
add_1_day = datetime.timedelta(days=1)
add_20_min = datetime.timedelta(minutes=20)

'''
allAns[x,y,z]
[x]: Segment (AM & PM, total 14)
[y]: timestamp (6 [20mins])
[z]: 3 features
'''
# allAns[0,:,1]
# Out:
# [[ 137.42771459]
#  [ 144.24861261]
#  [ 156.09394832]
#  [ 165.57232386]
#  [ 175.51834725]
#  [ 185.95908514]]
# [[ 139.31042082]
#  [ 145.20383747]
#  [ 149.42933163]
#  [ 152.71058138]
#  [ 159.35184389]
#  [ 164.1891575 ]]
# [[ 110.42359754]
#  [ 123.94496943]
#  [ 132.95049805]
#  [ 145.26874369]
#  [ 154.14242092]
#  [ 161.2233036 ]]
# [[ 133.15096823]
#  [ 141.42035676]
#  [ 144.11192246]
#  [ 148.05554862]
#  [ 151.61362486]
#  [ 154.35174581]]
# [[ 129.44622397]
#  [ 137.34187863]
#  [ 145.94389692]
#  [ 152.75677578]
#  [ 159.64179557]
#  [ 166.95789648]]
# [[ 141.83115015]
#  [ 142.31468947]
#  [ 145.15419216]
#  [ 147.763912  ]
#  [ 150.0574973 ]
#  [ 152.61486415]]
# [[ 116.41826375]
#  [ 124.0599363 ]
#  [ 130.36398441]
#  [ 135.69383837]
#  [ 139.89267551]
#  [ 145.72111963]]
# [[ 150.68750416]
#  [ 150.34097365]
#  [ 151.81444611]
#  [ 152.48998841]
#  [ 153.70002592]
#  [ 154.95606725]]
# [[ 128.89715944]
#  [ 136.37567594]
#  [ 142.7038288 ]
#  [ 146.37485075]
#  [ 150.53059868]
#  [ 154.21581565]]
# [[ 144.8564395 ]
#  [ 138.18233399]
#  [ 137.35933297]
#  [ 137.87989592]
#  [ 136.73527771]
#  [ 136.61552088]]
# [[ 122.56953482]
#  [ 125.78475647]
#  [ 126.82076715]
#  [ 127.30829242]
#  [ 128.88261095]
#  [ 130.85498867]]
# [[ 158.37511725]
#  [ 133.59223349]
#  [ 138.30199675]
#  [ 139.83699146]
#  [ 139.47925934]
#  [ 132.38847254]]
# [[ 121.09823861]
#  [ 135.32058601]
#  [ 148.86015462]
#  [ 157.03135963]
#  [ 164.96570793]
#  [ 172.92570494]]
# [[ 132.15428313]
#  [ 138.58307725]
#  [ 142.99332721]
#  [ 150.17593823]
#  [ 154.40176324]
#  [ 159.67838194]]
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/Kin/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# '\nallAns[x,y,z]\n[x]: Segment (AM & PM, total 14)\n[y]: timestamp (6 ins])\n[z]: 3 features\n'

# %%
for i in allAns:
    print(i)
# Out:
# [[ 137.42771459]
#  [ 144.24861261]
#  [ 156.09394832]
#  [ 165.57232386]
#  [ 175.51834725]
#  [ 185.95908514]]
# [[ 139.31042082]
#  [ 145.20383747]
#  [ 149.42933163]
#  [ 152.71058138]
#  [ 159.35184389]
#  [ 164.1891575 ]]
# [[ 110.42359754]
#  [ 123.94496943]
#  [ 132.95049805]
#  [ 145.26874369]
#  [ 154.14242092]
#  [ 161.2233036 ]]
# [[ 133.15096823]
#  [ 141.42035676]
#  [ 144.11192246]
#  [ 148.05554862]
#  [ 151.61362486]
#  [ 154.35174581]]
# [[ 129.44622397]
#  [ 137.34187863]
#  [ 145.94389692]
#  [ 152.75677578]
#  [ 159.64179557]
#  [ 166.95789648]]
# [[ 141.83115015]
#  [ 142.31468947]
#  [ 145.15419216]
#  [ 147.763912  ]
#  [ 150.0574973 ]
#  [ 152.61486415]]
# [[ 116.41826375]
#  [ 124.0599363 ]
#  [ 130.36398441]
#  [ 135.69383837]
#  [ 139.89267551]
#  [ 145.72111963]]
# [[ 150.68750416]
#  [ 150.34097365]
#  [ 151.81444611]
#  [ 152.48998841]
#  [ 153.70002592]
#  [ 154.95606725]]
# [[ 128.89715944]
#  [ 136.37567594]
#  [ 142.7038288 ]
#  [ 146.37485075]
#  [ 150.53059868]
#  [ 154.21581565]]
# [[ 144.8564395 ]
#  [ 138.18233399]
#  [ 137.35933297]
#  [ 137.87989592]
#  [ 136.73527771]
#  [ 136.61552088]]
# [[ 122.56953482]
#  [ 125.78475647]
#  [ 126.82076715]
#  [ 127.30829242]
#  [ 128.88261095]
#  [ 130.85498867]]
# [[ 158.37511725]
#  [ 133.59223349]
#  [ 138.30199675]
#  [ 139.83699146]
#  [ 139.47925934]
#  [ 132.38847254]]
# [[ 121.09823861]
#  [ 135.32058601]
#  [ 148.86015462]
#  [ 157.03135963]
#  [ 164.96570793]
#  [ 172.92570494]]
# [[ 132.15428313]
#  [ 138.58307725]
#  [ 142.99332721]
#  [ 150.17593823]
#  [ 154.40176324]
#  [ 159.67838194]]

# %%
# 11.a [FOR TRAFFIC TIME] Output the CSV file

## --- (For checking Phase1 Test_answer only)
''' For checking Answer'''
df_check_answer = df_pred_sel[ ((df_pred_sel.timeofday>= 8) & (df_pred_sel.timeofday<10)) |
                            ((df_pred_sel.timeofday>=17) & (df_pred_sel.timeofday<19))]

df_check_answer = df_check_answer[using_cols]
df_check_answer = df_check_answer["('B', 1)"]
check_ans_arr = df_check_answer.values

check_ans_arr[0]

## --- End of Check

route = 'B'
checkpoint = '1'
vol_or_traj = 0  # select the output cell

with open('{}-{}_only_checking_phase1.csv'.format(route, checkpoint), 'w') as f:
    for day in range(7):
        for am_pm in range(2):
            if am_pm == 0:
                ref_time = start_8am
            else:
                ref_time = start_5pm
            for timestep in range(6):
                start_timestamp = ref_time + day*add_1_day + timestep*add_20_min
                end_timestamp = start_timestamp + add_20_min
                start_timestr = start_timestamp.strftime("%Y-%m-%d %H:%M:00")
                end_timestr = end_timestamp.strftime("%Y-%m-%d %H:%M:00")
                f.write('{},{},"[{},{})",{},{}\n'.format(route,
                                                      checkpoint,
                                                      start_timestr,
                                                      end_timestr,
                                                      allAns[day*2+am_pm, timestep, vol_or_traj ],
                                                      check_ans_arr[day*2*6 + am_pm*6 + timestep]))  # This last value is for checking answer only

# %%
# 11.b [FOR VOLUME] Output the CSV file

# checkpoint = '2'
# direction = '0'
# vol_or_traj = 1  # select the output cell

# with open('{}-{}.csv'.format(checkpoint, direction), 'w') as f:
#     for day in range(7):
#         for am_pm in range(2):
#             if am_pm == 0:
#                 ref_time = start_8am
#             else:
#                 ref_time = start_5pm
#             for timestep in range(6):
#                 start_timestamp = ref_time + day*add_1_day + timestep*add_20_min
#                 end_timestamp = start_timestamp + add_20_min
#                 start_timestr = start_timestamp.strftime("%Y-%m-%d %H:%M:00")
#                 end_timestr = end_timestamp.strftime("%Y-%m-%d %H:%M:00")
#                 f.write('{},"[{},{})",{},{}\n'.format(checkpoint,
#                                                   start_timestr,
#                                                   end_timestr,
#                                                   direction,
#                                                   allAns[day*2+am_pm, timestep, vol_or_traj ]))
